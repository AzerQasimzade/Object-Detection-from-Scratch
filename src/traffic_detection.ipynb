# %% [markdown]
# Cell 1 — I check my environment
#
# I checked my Python environment and verified that OpenCV and Ultralytics are installed correctly.
# I also checked the Python version that my notebook is using

# %%
import sys
import cv2
import ultralytics

print("Python:", sys.version)
print("OpenCV:", cv2.__version__)
print("Ultralytics:", ultralytics.__version__)
# Out:
# Python: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]
# OpenCV: 5.0.0
# Ultralytics: 8.4.126

# %% [markdown]
# Then,
# I loaded a pretrained YOLO model using Ultralytics. I started with the nano version because it is lightweight and fast for testing.

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
